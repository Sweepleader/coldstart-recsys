# %% [markdown]
# # 基线塔

# %% [markdown]
# python models/behavior_tower_experiments/run_profile.py --profile baseline --out_csv models/behavior_tower_experiments/result/baseline_profile_50epochs.csv

# %% [markdown]
# Epoch 1 AvgLoss=0.672580
# Eval Recall@10=0.2951 NDCG@10=0.1469
#
# Epoch 2 AvgLoss=0.624471
# Eval Recall@10=0.3675 NDCG@10=0.1859
#
# Epoch 3 AvgLoss=0.585424
# Eval Recall@10=0.3919 NDCG@10=0.1984
#
# Epoch 4 AvgLoss=0.553355
# Eval Recall@10=0.4000 NDCG@10=0.2032
#
# Epoch 5 AvgLoss=0.527583
# Eval Recall@10=0.4069 NDCG@10=0.2067
#
# Epoch 6 AvgLoss=0.507379
# Eval Recall@10=0.4068 NDCG@10=0.2065
#
# Epoch 7 AvgLoss=0.490819
# Eval Recall@10=0.4062 NDCG@10=0.2069
#
# Epoch 8 AvgLoss=0.476758
# Eval Recall@10=0.4091 NDCG@10=0.2092
#
# Epoch 9 AvgLoss=0.465423
# Eval Recall@10=0.4083 NDCG@10=0.2095
#
# Epoch 10        AvgLoss=0.455958
# Eval Recall@10=0.4138 NDCG@10=0.2120
#
# Epoch 11        AvgLoss=0.447942
# Eval Recall@10=0.4168 NDCG@10=0.2129
#
# Epoch 12        AvgLoss=0.441116
# Eval Recall@10=0.4164 NDCG@10=0.2145
#
# Epoch 13        AvgLoss=0.435517
# Eval Recall@10=0.4075 NDCG@10=0.2082
#
# Epoch 14        AvgLoss=0.434434
# Eval Recall@10=0.4170 NDCG@10=0.2160
#
# Epoch 15        AvgLoss=0.427808
# Eval Recall@10=0.4181 NDCG@10=0.2180
#
# Epoch 16        AvgLoss=0.423287
# Eval Recall@10=0.4212 NDCG@10=0.2201
#
# Epoch 17        AvgLoss=0.419499
# Eval Recall@10=0.4224 NDCG@10=0.2222
#
# Epoch 18        AvgLoss=0.416273
# Eval Recall@10=0.4245 NDCG@10=0.2234
#
# Epoch 19        AvgLoss=0.413644
# Eval Recall@10=0.4258 NDCG@10=0.2222
#
# Epoch 20        AvgLoss=0.410924
# Eval Recall@10=0.4335 NDCG@10=0.2269
#
# Epoch 21        AvgLoss=0.408596
# Eval Recall@10=0.4299 NDCG@10=0.2258
#
# Epoch 22        AvgLoss=0.406458
# Eval Recall@10=0.4369 NDCG@10=0.2299
#
# Epoch 23        AvgLoss=0.404592
# Eval Recall@10=0.4335 NDCG@10=0.2271
#
# Epoch 24        AvgLoss=0.402889
# Eval Recall@10=0.4395 NDCG@10=0.2300
#
# Epoch 25        AvgLoss=0.401318
# Eval Recall@10=0.4399 NDCG@10=0.2300
#
# Epoch 26        AvgLoss=0.399889
# Eval Recall@10=0.4400 NDCG@10=0.2298
#
# Epoch 27        AvgLoss=0.398522
# Eval Recall@10=0.4452 NDCG@10=0.2309
#
# Epoch 28        AvgLoss=0.397501
# Eval Recall@10=0.4419 NDCG@10=0.2286
#
# Epoch 29        AvgLoss=0.396451
# Eval Recall@10=0.4404 NDCG@10=0.2287
#
# Epoch 30        AvgLoss=0.395379
# Eval Recall@10=0.4447 NDCG@10=0.2296
#
# Epoch 31        AvgLoss=0.394267
# Eval Recall@10=0.4461 NDCG@10=0.2312
#
# Epoch 32        AvgLoss=0.393286
# Eval Recall@10=0.4449 NDCG@10=0.2300
#
# Epoch 33        AvgLoss=0.392473
# Eval Recall@10=0.4491 NDCG@10=0.2309
#
# Epoch 34        AvgLoss=0.391676
# Eval Recall@10=0.4476 NDCG@10=0.2313
#
# Epoch 35        AvgLoss=0.390910
# Eval Recall@10=0.4501 NDCG@10=0.2309
#
# Epoch 36        AvgLoss=0.390239
# Eval Recall@10=0.4516 NDCG@10=0.2329
#
# Epoch 37        AvgLoss=0.389579
# Eval Recall@10=0.4500 NDCG@10=0.2313
#
# Epoch 38        AvgLoss=0.389002
# Eval Recall@10=0.4551 NDCG@10=0.2325
#
# Epoch 39        AvgLoss=0.388517
# Eval Recall@10=0.4499 NDCG@10=0.2326
#
# Epoch 40        AvgLoss=0.387925
# Eval Recall@10=0.4563 NDCG@10=0.2336
#
# Epoch 41        AvgLoss=0.387263
# Eval Recall@10=0.4542 NDCG@10=0.2350
#
# Epoch 42        AvgLoss=0.386763
# Eval Recall@10=0.4516 NDCG@10=0.2317
#
# Epoch 43        AvgLoss=0.394628
# Eval Recall@10=0.4511 NDCG@10=0.2301
#
# Epoch 44        AvgLoss=0.390887
# Eval Recall@10=0.4548 NDCG@10=0.2327
#
# Epoch 45        AvgLoss=0.388500
# Eval Recall@10=0.4545 NDCG@10=0.2321
#
# Epoch 46        AvgLoss=0.386864
# Eval Recall@10=0.4549 NDCG@10=0.2323
#
# Epoch 47        AvgLoss=0.385723
# Eval Recall@10=0.4541 NDCG@10=0.2322
#
# Epoch 48        AvgLoss=0.384969
# Eval Recall@10=0.4573 NDCG@10=0.2326
#
# Epoch 49        AvgLoss=0.384368
# Eval Recall@10=0.4601 NDCG@10=0.2335
#
# Epoch 50        AvgLoss=0.383873
# Eval Recall@10=0.4570 NDCG@10=0.2328
#
# Recall@10=0.4586 NDCG@10=0.2338

# %% [markdown]
# # 基线塔 + 双层GRU

# %% [markdown]
# Epoch 1 AvgLoss=0.662838
# Eval Recall@10=0.3230 NDCG@10=0.1638
#
# Epoch 2 AvgLoss=0.614246
# Eval Recall@10=0.3779 NDCG@10=0.1925
#
# Epoch 3 AvgLoss=0.573901
# Eval Recall@10=0.3990 NDCG@10=0.2033
#
# Epoch 4 AvgLoss=0.542460
# Eval Recall@10=0.4054 NDCG@10=0.2061
#
# Epoch 5 AvgLoss=0.518141
# Eval Recall@10=0.4068 NDCG@10=0.2065
#
# Epoch 6 AvgLoss=0.498948
# Eval Recall@10=0.4094 NDCG@10=0.2085
#
# Epoch 7 AvgLoss=0.483670
# Eval Recall@10=0.4056 NDCG@10=0.2075
#
# Epoch 8 AvgLoss=0.471832
# Eval Recall@10=0.4091 NDCG@10=0.2092
#
# Epoch 9 AvgLoss=0.461228
# Eval Recall@10=0.4070 NDCG@10=0.2095
#
# Epoch 10        AvgLoss=0.452702
# Eval Recall@10=0.4142 NDCG@10=0.2134
#
# Epoch 11        AvgLoss=0.445432
# Eval Recall@10=0.4163 NDCG@10=0.2133
#
# Epoch 12        AvgLoss=0.439026
# Eval Recall@10=0.4143 NDCG@10=0.2136
#
# Epoch 13        AvgLoss=0.433577
# Eval Recall@10=0.4153 NDCG@10=0.2133
#
# Epoch 14        AvgLoss=0.429396
# Eval Recall@10=0.4187 NDCG@10=0.2171
#
# Epoch 15        AvgLoss=0.424902
# Eval Recall@10=0.4183 NDCG@10=0.2178
#
# Epoch 16        AvgLoss=0.421189
# Eval Recall@10=0.4223 NDCG@10=0.2198
#
# Epoch 17        AvgLoss=0.417956
# Eval Recall@10=0.4224 NDCG@10=0.2217
#
# Epoch 18        AvgLoss=0.415179
# Eval Recall@10=0.4206 NDCG@10=0.2201
#
# Epoch 19        AvgLoss=0.412689
# Eval Recall@10=0.4234 NDCG@10=0.2210
#
# Epoch 20        AvgLoss=0.410336
# Eval Recall@10=0.4301 NDCG@10=0.2249
#
# Epoch 21        AvgLoss=0.408231
# Eval Recall@10=0.4286 NDCG@10=0.2248
#
# Epoch 22        AvgLoss=0.406324
# Eval Recall@10=0.4310 NDCG@10=0.2271
#
# Epoch 23        AvgLoss=0.404502
# Eval Recall@10=0.4344 NDCG@10=0.2282
#
# Epoch 24        AvgLoss=0.402902
# Eval Recall@10=0.4365 NDCG@10=0.2288
#
# Epoch 25        AvgLoss=0.401404
# Eval Recall@10=0.4379 NDCG@10=0.2288
#
# Epoch 26        AvgLoss=0.400159
# Eval Recall@10=0.4380 NDCG@10=0.2304
#
# Epoch 27        AvgLoss=0.398882
# Eval Recall@10=0.4435 NDCG@10=0.2300
#
# Epoch 28        AvgLoss=0.397591
# Eval Recall@10=0.4384 NDCG@10=0.2284
#
# Epoch 29        AvgLoss=0.396561
# Eval Recall@10=0.4432 NDCG@10=0.2295
#
# Epoch 30        AvgLoss=0.395585
# Eval Recall@10=0.4426 NDCG@10=0.2298
#
# Epoch 31        AvgLoss=0.394651
# Eval Recall@10=0.4491 NDCG@10=0.2332
#
# Epoch 32        AvgLoss=0.393757
# Eval Recall@10=0.4431 NDCG@10=0.2289
#
# Epoch 33        AvgLoss=0.392921
# Eval Recall@10=0.4472 NDCG@10=0.2315
#
# Epoch 34        AvgLoss=0.392112
# Eval Recall@10=0.4456 NDCG@10=0.2309
#
# Epoch 35        AvgLoss=0.391388
# Eval Recall@10=0.4472 NDCG@10=0.2311
#
# Epoch 36        AvgLoss=0.390688
# Eval Recall@10=0.4495 NDCG@10=0.2320
#
# Epoch 37        AvgLoss=0.390019
# Eval Recall@10=0.4524 NDCG@10=0.2325
#
# Epoch 38        AvgLoss=0.393951
# Eval Recall@10=0.4471 NDCG@10=0.2280
#
# Epoch 39        AvgLoss=0.392251
# Eval Recall@10=0.4492 NDCG@10=0.2309
#
# Epoch 40        AvgLoss=0.390029
# Eval Recall@10=0.4550 NDCG@10=0.2316
#
# Epoch 41        AvgLoss=0.388738
# Eval Recall@10=0.4547 NDCG@10=0.2337
#
# Epoch 42        AvgLoss=0.387940
# Eval Recall@10=0.4509 NDCG@10=0.2316
#
# Epoch 43        AvgLoss=0.387293
# Eval Recall@10=0.4570 NDCG@10=0.2344
#
# Epoch 44        AvgLoss=0.386649
# Eval Recall@10=0.4602 NDCG@10=0.2339
#
# Epoch 45        AvgLoss=0.386195
# Eval Recall@10=0.4565 NDCG@10=0.2327
#
# Epoch 46        AvgLoss=0.385755
# Eval Recall@10=0.4554 NDCG@10=0.2323
#
# Epoch 47        AvgLoss=0.385252
# Eval Recall@10=0.4543 NDCG@10=0.2331
#
# Epoch 48        AvgLoss=0.384843
# Eval Recall@10=0.4583 NDCG@10=0.2328
#
# Epoch 49        AvgLoss=0.384414
# Eval Recall@10=0.4597 NDCG@10=0.2332
#
# Epoch 50        AvgLoss=0.384038
# Eval Recall@10=0.4573 NDCG@10=0.2327
#
# Recall@10=0.4592 NDCG@10=0.2342

# %% [markdown]
# # 基线塔 + 双向GRU

# %% [markdown]
# Epoch 1 AvgLoss=0.665700
# Eval Recall@10=0.3132 NDCG@10=0.1583
#
# Epoch 2 AvgLoss=0.618444
# Eval Recall@10=0.3769 NDCG@10=0.1908
#
# Epoch 3 AvgLoss=0.579561
# Eval Recall@10=0.3988 NDCG@10=0.2024
#
# Epoch 4 AvgLoss=0.547780
# Eval Recall@10=0.4062 NDCG@10=0.2063
#
# Epoch 5 AvgLoss=0.522590
# Eval Recall@10=0.4076 NDCG@10=0.2070
#
# Epoch 6 AvgLoss=0.502731
# Eval Recall@10=0.4113 NDCG@10=0.2100
#
# Epoch 7 AvgLoss=0.486464
# Eval Recall@10=0.4088 NDCG@10=0.2085
#
# Epoch 8 AvgLoss=0.473343
# Eval Recall@10=0.4137 NDCG@10=0.2111
#
# Epoch 9 AvgLoss=0.462394
# Eval Recall@10=0.4109 NDCG@10=0.2111
#
# Epoch 10        AvgLoss=0.453264
# Eval Recall@10=0.4194 NDCG@10=0.2149
#
# Epoch 11        AvgLoss=0.445435
# Eval Recall@10=0.4214 NDCG@10=0.2153
#
# Epoch 12        AvgLoss=0.438809
# Eval Recall@10=0.4199 NDCG@10=0.2162
#
# Epoch 13        AvgLoss=0.433152
# Eval Recall@10=0.4215 NDCG@10=0.2167
#
# Epoch 14        AvgLoss=0.428163
# Eval Recall@10=0.4249 NDCG@10=0.2198
#
# Epoch 15        AvgLoss=0.423779
# Eval Recall@10=0.4229 NDCG@10=0.2202
#
# Epoch 16        AvgLoss=0.419899
# Eval Recall@10=0.4280 NDCG@10=0.2223
#
# Epoch 17        AvgLoss=0.416796
# Eval Recall@10=0.4268 NDCG@10=0.2218
#
# Epoch 18        AvgLoss=0.413471
# Eval Recall@10=0.4300 NDCG@10=0.2251
#
# Epoch 19        AvgLoss=0.410646
# Eval Recall@10=0.4325 NDCG@10=0.2246
#
# Epoch 20        AvgLoss=0.408165
# Eval Recall@10=0.4377 NDCG@10=0.2291
#
# Epoch 21        AvgLoss=0.405963
# Eval Recall@10=0.4369 NDCG@10=0.2293
#
# Epoch 22        AvgLoss=0.404051
# Eval Recall@10=0.4424 NDCG@10=0.2323
#
# Epoch 23        AvgLoss=0.402284
# Eval Recall@10=0.4406 NDCG@10=0.2318
#
# Epoch 24        AvgLoss=0.400641
# Eval Recall@10=0.4455 NDCG@10=0.2320
#
# Epoch 25        AvgLoss=0.399094
# Eval Recall@10=0.4456 NDCG@10=0.2324
#
# Epoch 26        AvgLoss=0.397579
# Eval Recall@10=0.4478 NDCG@10=0.2344
#
# Epoch 27        AvgLoss=0.396288
# Eval Recall@10=0.4503 NDCG@10=0.2342
#
# Epoch 28        AvgLoss=0.395087
# Eval Recall@10=0.4482 NDCG@10=0.2326
#
# Epoch 29        AvgLoss=0.394026
# Eval Recall@10=0.4484 NDCG@10=0.2338
#
# Epoch 30        AvgLoss=0.393024
# Eval Recall@10=0.4515 NDCG@10=0.2327
#
# Epoch 31        AvgLoss=0.392041
# Eval Recall@10=0.4526 NDCG@10=0.2342
#
# Epoch 32        AvgLoss=0.391172
# Eval Recall@10=0.4512 NDCG@10=0.2327
#
# Epoch 33        AvgLoss=0.390359
# Eval Recall@10=0.4558 NDCG@10=0.2337
#
# Epoch 34        AvgLoss=0.389630
# Eval Recall@10=0.4537 NDCG@10=0.2334
#
# Epoch 35        AvgLoss=0.388878
# Eval Recall@10=0.4566 NDCG@10=0.2338
#
# Epoch 36        AvgLoss=0.388188
# Eval Recall@10=0.4601 NDCG@10=0.2354
#
# Epoch 37        AvgLoss=0.387490
# Eval Recall@10=0.4580 NDCG@10=0.2341
#
# Epoch 38        AvgLoss=0.386879
# Eval Recall@10=0.4602 NDCG@10=0.2348
#
# Epoch 39        AvgLoss=0.386258
# Eval Recall@10=0.4567 NDCG@10=0.2352
#
# Epoch 40        AvgLoss=0.385697
# Eval Recall@10=0.4639 NDCG@10=0.2351
#
# Epoch 41        AvgLoss=0.385190
# Eval Recall@10=0.4629 NDCG@10=0.2369
#
# Epoch 42        AvgLoss=0.384726
# Eval Recall@10=0.4593 NDCG@10=0.2353
#
# Epoch 43        AvgLoss=0.384221
# Eval Recall@10=0.4637 NDCG@10=0.2368
#
# Epoch 44        AvgLoss=0.383779
# Eval Recall@10=0.4645 NDCG@10=0.2371
#
# Epoch 45        AvgLoss=0.383326
# Eval Recall@10=0.4627 NDCG@10=0.2362
#
# Epoch 46        AvgLoss=0.382879
# Eval Recall@10=0.4610 NDCG@10=0.2352
#
# Epoch 47        AvgLoss=0.382484
# Eval Recall@10=0.4620 NDCG@10=0.2358
#
# Epoch 48        AvgLoss=0.382012
# Eval Recall@10=0.4642 NDCG@10=0.2354
#
# Epoch 49        AvgLoss=0.381697
# Eval Recall@10=0.4641 NDCG@10=0.2369
#
# Epoch 50        AvgLoss=0.381302
# Eval Recall@10=0.4636 NDCG@10=0.2358
#
# Recall@10=0.4639 NDCG@10=0.2366

# %% [markdown]
# # 基线塔 + 双向GRU + 双层GRU

# %% [markdown]
# Epoch 1 AvgLoss=0.660272
# Eval Recall@10=0.3321 NDCG@10=0.1697
#
# Epoch 2 AvgLoss=0.611850
# Eval Recall@10=0.3910 NDCG@10=0.1991
#
# Epoch 3 AvgLoss=0.572738
# Eval Recall@10=0.4054 NDCG@10=0.2055
#
# Epoch 4 AvgLoss=0.542211
# Eval Recall@10=0.4104 NDCG@10=0.2086
#
# Epoch 5 AvgLoss=0.517837
# Eval Recall@10=0.4099 NDCG@10=0.2087
#
# Epoch 6 AvgLoss=0.498853
# Eval Recall@10=0.4106 NDCG@10=0.2088
#
# Epoch 7 AvgLoss=0.483424
# Eval Recall@10=0.4116 NDCG@10=0.2102
#
# Epoch 8 AvgLoss=0.471120
# Eval Recall@10=0.4145 NDCG@10=0.2116
#
# Epoch 9 AvgLoss=0.460397
# Eval Recall@10=0.4134 NDCG@10=0.2121
#
# Epoch 10        AvgLoss=0.451419
# Eval Recall@10=0.4219 NDCG@10=0.2173
#
# Epoch 11        AvgLoss=0.443843
# Eval Recall@10=0.4232 NDCG@10=0.2172
#
# Epoch 12        AvgLoss=0.437304
# Eval Recall@10=0.4239 NDCG@10=0.2179
#
# Epoch 13        AvgLoss=0.431645
# Eval Recall@10=0.4239 NDCG@10=0.2180
#
# Epoch 14        AvgLoss=0.426845
# Eval Recall@10=0.4257 NDCG@10=0.2201
#
# Epoch 15        AvgLoss=0.422514
# Eval Recall@10=0.4232 NDCG@10=0.2197
#
# Epoch 16        AvgLoss=0.418631
# Eval Recall@10=0.4299 NDCG@10=0.2246
#
# Epoch 17        AvgLoss=0.415324
# Eval Recall@10=0.4286 NDCG@10=0.2242
#
# Epoch 18        AvgLoss=0.412142
# Eval Recall@10=0.4328 NDCG@10=0.2262
#
# Epoch 19        AvgLoss=0.409450
# Eval Recall@10=0.4376 NDCG@10=0.2279
#
# Epoch 20        AvgLoss=0.407465
# Eval Recall@10=0.4390 NDCG@10=0.2288
#
# Epoch 21        AvgLoss=0.405075
# Eval Recall@10=0.4394 NDCG@10=0.2295
#
# Epoch 22        AvgLoss=0.402996
# Eval Recall@10=0.4408 NDCG@10=0.2315
#
# Epoch 23        AvgLoss=0.401182
# Eval Recall@10=0.4433 NDCG@10=0.2316
#
# Epoch 24        AvgLoss=0.399483
# Eval Recall@10=0.4469 NDCG@10=0.2317
#
# Epoch 25        AvgLoss=0.398034
# Eval Recall@10=0.4476 NDCG@10=0.2316
#
# Epoch 26        AvgLoss=0.396663
# Eval Recall@10=0.4476 NDCG@10=0.2309
#
# Epoch 27        AvgLoss=0.395451
# Eval Recall@10=0.4529 NDCG@10=0.2329
#
# Epoch 28        AvgLoss=0.394339
# Eval Recall@10=0.4482 NDCG@10=0.2317
#
# Epoch 29        AvgLoss=0.393216
# Eval Recall@10=0.4512 NDCG@10=0.2336
#
# Epoch 30        AvgLoss=0.392235
# Eval Recall@10=0.4497 NDCG@10=0.2319
#
# Epoch 31        AvgLoss=0.391248
# Eval Recall@10=0.4522 NDCG@10=0.2344
#
# Epoch 32        AvgLoss=0.390387
# Eval Recall@10=0.4502 NDCG@10=0.2316
#
# Epoch 33        AvgLoss=0.389617
# Eval Recall@10=0.4559 NDCG@10=0.2347
#
# Epoch 34        AvgLoss=0.388873
# Eval Recall@10=0.4570 NDCG@10=0.2348
#
# Epoch 35        AvgLoss=0.388109
# Eval Recall@10=0.4572 NDCG@10=0.2340
#
# Epoch 36        AvgLoss=0.387487
# Eval Recall@10=0.4573 NDCG@10=0.2347
#
# Epoch 37        AvgLoss=0.386868
# Eval Recall@10=0.4595 NDCG@10=0.2351
#
# Epoch 38        AvgLoss=0.386260
# Eval Recall@10=0.4617 NDCG@10=0.2352
#
# Epoch 39        AvgLoss=0.385567
# Eval Recall@10=0.4559 NDCG@10=0.2347
#
# Epoch 40        AvgLoss=0.385005
# Eval Recall@10=0.4624 NDCG@10=0.2344
#
# Epoch 41        AvgLoss=0.384502
# Eval Recall@10=0.4602 NDCG@10=0.2364
#
# Epoch 42        AvgLoss=0.383994
# Eval Recall@10=0.4606 NDCG@10=0.2353
#
# Epoch 43        AvgLoss=0.383541
# Eval Recall@10=0.4613 NDCG@10=0.2363
#
# Epoch 44        AvgLoss=0.383053
# Eval Recall@10=0.4664 NDCG@10=0.2382
#
# Epoch 45        AvgLoss=0.382709
# Eval Recall@10=0.4642 NDCG@10=0.2362
#
# Epoch 46        AvgLoss=0.382192
# Eval Recall@10=0.4627 NDCG@10=0.2355
#
# Epoch 47        AvgLoss=0.381868
# Eval Recall@10=0.4622 NDCG@10=0.2349
#
# Epoch 48        AvgLoss=0.381435
# Eval Recall@10=0.4652 NDCG@10=0.2356
#
# Epoch 49        AvgLoss=0.381136
# Eval Recall@10=0.4649 NDCG@10=0.2361
#
# Epoch 50        AvgLoss=0.380754
# Eval Recall@10=0.4631 NDCG@10=0.2359
#
# Recall@10=0.4637 NDCG@10=0.2357

# %% [markdown]
# # 改进塔

# %% [markdown]
# ### 改进塔 last池化

# %% [markdown]
# python models/behavior_tower_experiments/run_profile.py --profile improved_last --out_csv models/behavior_tower_experiments/result/improved_last_profile_30epochs.csv

# %% [markdown]
# Epoch 1 AvgLoss=0.673197
# Eval Recall@10=0.2932 NDCG@10=0.1466
#
# Epoch 2 AvgLoss=0.625092
# Eval Recall@10=0.3683 NDCG@10=0.1861
#
# Epoch 3 AvgLoss=0.586025
# Eval Recall@10=0.3908 NDCG@10=0.1977
#
# Epoch 4 AvgLoss=0.554008
# Eval Recall@10=0.3997 NDCG@10=0.2029
#
# Epoch 5 AvgLoss=0.528086
# Eval Recall@10=0.4053 NDCG@10=0.2063
#
# Epoch 6 AvgLoss=0.507743
# Eval Recall@10=0.4036 NDCG@10=0.2042
#
# Epoch 7 AvgLoss=0.492344
# Eval Recall@10=0.4037 NDCG@10=0.2050
#
# Epoch 8 AvgLoss=0.478688
# Eval Recall@10=0.4070 NDCG@10=0.2068
#
# Epoch 9 AvgLoss=0.467451
# Eval Recall@10=0.4046 NDCG@10=0.2064
#
# Epoch 10        AvgLoss=0.458123
# Eval Recall@10=0.4093 NDCG@10=0.2095
#
# Epoch 11        AvgLoss=0.450201
# Eval Recall@10=0.4131 NDCG@10=0.2097
#
# Epoch 12        AvgLoss=0.443445
# Eval Recall@10=0.4124 NDCG@10=0.2103
#
# Epoch 13        AvgLoss=0.437642
# Eval Recall@10=0.4136 NDCG@10=0.2125
#
# Epoch 14        AvgLoss=0.432585
# Eval Recall@10=0.4153 NDCG@10=0.2144
#
# Epoch 15        AvgLoss=0.428148
# Eval Recall@10=0.4152 NDCG@10=0.2155
#
# Epoch 16        AvgLoss=0.424369
# Eval Recall@10=0.4189 NDCG@10=0.2183
#
# Epoch 17        AvgLoss=0.420889
# Eval Recall@10=0.4184 NDCG@10=0.2194
#
# Epoch 18        AvgLoss=0.417781
# Eval Recall@10=0.4202 NDCG@10=0.2211
#
# Epoch 19        AvgLoss=0.415041
# Eval Recall@10=0.4234 NDCG@10=0.2216
#
# Epoch 20        AvgLoss=0.412549
# Eval Recall@10=0.4289 NDCG@10=0.2247
#
# Epoch 21        AvgLoss=0.410509
# Eval Recall@10=0.4289 NDCG@10=0.2261
#
# Epoch 22        AvgLoss=0.408336
# Eval Recall@10=0.4328 NDCG@10=0.2281
#
# Epoch 23        AvgLoss=0.407644
# Eval Recall@10=0.4289 NDCG@10=0.2257
#
# Epoch 24        AvgLoss=0.405321
# Eval Recall@10=0.4369 NDCG@10=0.2279
#
# Epoch 25        AvgLoss=0.403456
# Eval Recall@10=0.4385 NDCG@10=0.2285
#
# Epoch 26        AvgLoss=0.401893
# Eval Recall@10=0.4380 NDCG@10=0.2286
#
# Epoch 27        AvgLoss=0.400628
# Eval Recall@10=0.4427 NDCG@10=0.2292
#
# Epoch 28        AvgLoss=0.399402
# Eval Recall@10=0.4424 NDCG@10=0.2280
#
# Epoch 29        AvgLoss=0.398239
# Eval Recall@10=0.4420 NDCG@10=0.2285
#
# Epoch 30        AvgLoss=0.397180
# Eval Recall@10=0.4437 NDCG@10=0.2290
#
# Epoch 31        AvgLoss=0.396256
# Eval Recall@10=0.4482 NDCG@10=0.2309
#
# Epoch 32        AvgLoss=0.395331
# Eval Recall@10=0.4429 NDCG@10=0.2283
#
# Epoch 33        AvgLoss=0.394360
# Eval Recall@10=0.4470 NDCG@10=0.2296
#
# Epoch 34        AvgLoss=0.393617
# Eval Recall@10=0.4458 NDCG@10=0.2300
#
# Epoch 35        AvgLoss=0.392769
# Eval Recall@10=0.4496 NDCG@10=0.2297
#
# Epoch 36        AvgLoss=0.392158
# Eval Recall@10=0.4511 NDCG@10=0.2304
#
# Epoch 37        AvgLoss=0.391544
# Eval Recall@10=0.4496 NDCG@10=0.2301
#
# Epoch 38        AvgLoss=0.390764
# Eval Recall@10=0.4531 NDCG@10=0.2316
#
# Epoch 39        AvgLoss=0.390044
# Eval Recall@10=0.4505 NDCG@10=0.2312
#
# Epoch 40        AvgLoss=0.389398
# Eval Recall@10=0.4531 NDCG@10=0.2311
#
# Epoch 41        AvgLoss=0.388822
# Eval Recall@10=0.4532 NDCG@10=0.2322
#
# Epoch 42        AvgLoss=0.388243
# Eval Recall@10=0.4512 NDCG@10=0.2310
#
# Epoch 43        AvgLoss=0.387775
# Eval Recall@10=0.4546 NDCG@10=0.2315
#
# Epoch 44        AvgLoss=0.387291
# Eval Recall@10=0.4561 NDCG@10=0.2324
#
# Epoch 45        AvgLoss=0.386953
# Eval Recall@10=0.4556 NDCG@10=0.2316
#
# Epoch 46        AvgLoss=0.386390
# Eval Recall@10=0.4545 NDCG@10=0.2313
#
# Epoch 47        AvgLoss=0.385944
# Eval Recall@10=0.4536 NDCG@10=0.2316
#
# Epoch 48        AvgLoss=0.385536
# Eval Recall@10=0.4548 NDCG@10=0.2297
#
# Epoch 49        AvgLoss=0.385208
# Eval Recall@10=0.4586 NDCG@10=0.2321
#
# Epoch 50        AvgLoss=0.388686
# Eval Recall@10=0.4547 NDCG@10=0.2311
#
# Recall@10=0.4563 NDCG@10=0.2313

# %% [markdown]
# ### 改进塔 + 平均池化

# %% [markdown]
# python models/behavior_tower_experiments/run_profile.py --profile improved_mean --out_csv models/behavior_tower_experiments/result/improved_mean_profile_30epochs.csv

# %% [markdown]
# Epoch 1 AvgLoss=0.659076
# Eval Recall@10=0.1227 NDCG@10=0.0538
#
# Epoch 2 AvgLoss=0.644770
# Eval Recall@10=0.2077 NDCG@10=0.0942
#
# Epoch 3 AvgLoss=0.622965
# Eval Recall@10=0.3026 NDCG@10=0.1427
#
# Epoch 4 AvgLoss=0.597931
# Eval Recall@10=0.3540 NDCG@10=0.1718
#
# Epoch 5 AvgLoss=0.573360
# Eval Recall@10=0.3809 NDCG@10=0.1893
#
# Epoch 6 AvgLoss=0.551038
# Eval Recall@10=0.3950 NDCG@10=0.1978
#
# Epoch 7 AvgLoss=0.531503
# Eval Recall@10=0.4023 NDCG@10=0.2024
#
# Epoch 8 AvgLoss=0.514595
# Eval Recall@10=0.4060 NDCG@10=0.2066
#
# Epoch 9 AvgLoss=0.500103
# Eval Recall@10=0.4084 NDCG@10=0.2081
#
# Epoch 10        AvgLoss=0.487627
# Eval Recall@10=0.4130 NDCG@10=0.2113
#
# Epoch 11        AvgLoss=0.476954
# Eval Recall@10=0.4187 NDCG@10=0.2136
#
# Epoch 12        AvgLoss=0.467668
# Eval Recall@10=0.4167 NDCG@10=0.2132
#
# Epoch 13        AvgLoss=0.459798
# Eval Recall@10=0.4172 NDCG@10=0.2145
#
# Epoch 14        AvgLoss=0.452875
# Eval Recall@10=0.4183 NDCG@10=0.2165
#
# Epoch 15        AvgLoss=0.446886
# Eval Recall@10=0.4162 NDCG@10=0.2167
#
# Epoch 16        AvgLoss=0.441640
# Eval Recall@10=0.4215 NDCG@10=0.2197
#
# Epoch 17        AvgLoss=0.437091
# Eval Recall@10=0.4232 NDCG@10=0.2208
#
# Epoch 18        AvgLoss=0.433070
# Eval Recall@10=0.4223 NDCG@10=0.2212
#
# Epoch 19        AvgLoss=0.429538
# Eval Recall@10=0.4220 NDCG@10=0.2203
#
# Epoch 20        AvgLoss=0.426371
# Eval Recall@10=0.4269 NDCG@10=0.2232
#
# Epoch 21        AvgLoss=0.423581
# Eval Recall@10=0.4274 NDCG@10=0.2245
#
# Epoch 22        AvgLoss=0.421087
# Eval Recall@10=0.4288 NDCG@10=0.2259
#
# Epoch 23        AvgLoss=0.418833
# Eval Recall@10=0.4298 NDCG@10=0.2261
#
# Epoch 24        AvgLoss=0.416840
# Eval Recall@10=0.4304 NDCG@10=0.2257
#
# Epoch 25        AvgLoss=0.415030
# Eval Recall@10=0.4329 NDCG@10=0.2267
#
# Epoch 26        AvgLoss=0.413403
# Eval Recall@10=0.4338 NDCG@10=0.2266
#
# Epoch 27        AvgLoss=0.411917
# Eval Recall@10=0.4369 NDCG@10=0.2280
#
# Epoch 28        AvgLoss=0.410529
# Eval Recall@10=0.4360 NDCG@10=0.2263
#
# Epoch 29        AvgLoss=0.409280
# Eval Recall@10=0.4335 NDCG@10=0.2267
#
# Epoch 30        AvgLoss=0.408121
# Eval Recall@10=0.4374 NDCG@10=0.2290
#
# Epoch 31        AvgLoss=0.407059
# Eval Recall@10=0.4397 NDCG@10=0.2292
#
# Epoch 32        AvgLoss=0.406076
# Eval Recall@10=0.4369 NDCG@10=0.2285
#
# Epoch 33        AvgLoss=0.405161
# Eval Recall@10=0.4390 NDCG@10=0.2289
#
# Epoch 34        AvgLoss=0.404315
# Eval Recall@10=0.4395 NDCG@10=0.2287
#
# Epoch 35        AvgLoss=0.403499
# Eval Recall@10=0.4402 NDCG@10=0.2285
#
# Epoch 36        AvgLoss=0.402770
# Eval Recall@10=0.4418 NDCG@10=0.2293
#
# Epoch 37        AvgLoss=0.402068
# Eval Recall@10=0.4421 NDCG@10=0.2286
#
# Epoch 38        AvgLoss=0.401406
# Eval Recall@10=0.4430 NDCG@10=0.2294
#
# Epoch 39        AvgLoss=0.400806
# Eval Recall@10=0.4390 NDCG@10=0.2286
#
# Epoch 40        AvgLoss=0.400236
# Eval Recall@10=0.4444 NDCG@10=0.2294
#
# Epoch 41        AvgLoss=0.399660
# Eval Recall@10=0.4417 NDCG@10=0.2294
#
# Epoch 42        AvgLoss=0.399104
# Eval Recall@10=0.4439 NDCG@10=0.2283
#
# Epoch 43        AvgLoss=0.398636
# Eval Recall@10=0.4430 NDCG@10=0.2290
#
# Epoch 44        AvgLoss=0.398144
# Eval Recall@10=0.4476 NDCG@10=0.2302
#
# Epoch 45        AvgLoss=0.397673
# Eval Recall@10=0.4465 NDCG@10=0.2291
#
# Epoch 46        AvgLoss=0.397284
# Eval Recall@10=0.4452 NDCG@10=0.2292
#
# Epoch 47        AvgLoss=0.396816
# Eval Recall@10=0.4472 NDCG@10=0.2293
#
# Epoch 48        AvgLoss=0.396423
# Eval Recall@10=0.4437 NDCG@10=0.2279
#
# Epoch 49        AvgLoss=0.396059
# Eval Recall@10=0.4451 NDCG@10=0.2282
#
# Epoch 50        AvgLoss=0.395659
# Eval Recall@10=0.4467 NDCG@10=0.2302
#
# Recall@10=0.4457 NDCG@10=0.2282

# %% [markdown]
# ### 改进塔 + 平均池化 + drop 0.1

# %% [markdown]
# python models/behavior_tower_experiments/run_profile.py --profile improved_mean_decay --out_csv models/behavior_tower_experiments/result/improved_mean_decay_profile_50epochs.csv

# %% [markdown]
# Epoch 1 AvgLoss=0.671825
# Eval Recall@10=0.1070 NDCG@10=0.0468
#
# Epoch 2 AvgLoss=0.664414
# Eval Recall@10=0.1384 NDCG@10=0.0615
#
# Epoch 3 AvgLoss=0.652021
# Eval Recall@10=0.2040 NDCG@10=0.0933
#
# Epoch 4 AvgLoss=0.634531
# Eval Recall@10=0.2743 NDCG@10=0.1292
#
# Epoch 5 AvgLoss=0.613559
# Eval Recall@10=0.3277 NDCG@10=0.1582
#
# Epoch 6 AvgLoss=0.591458
# Eval Recall@10=0.3585 NDCG@10=0.1753
#
# Epoch 7 AvgLoss=0.570421
# Eval Recall@10=0.3791 NDCG@10=0.1868
#
# Epoch 8 AvgLoss=0.551142
# Eval Recall@10=0.3885 NDCG@10=0.1932
#
# Epoch 9 AvgLoss=0.534153
# Eval Recall@10=0.3916 NDCG@10=0.1971
#
# Epoch 10        AvgLoss=0.519058
# Eval Recall@10=0.4002 NDCG@10=0.2017
#
# Epoch 11        AvgLoss=0.505920
# Eval Recall@10=0.4036 NDCG@10=0.2039
#
# Epoch 12        AvgLoss=0.494358
# Eval Recall@10=0.4039 NDCG@10=0.2044
#
# Epoch 13        AvgLoss=0.484392
# Eval Recall@10=0.4061 NDCG@10=0.2064
#
# Epoch 14        AvgLoss=0.475664
# Eval Recall@10=0.4076 NDCG@10=0.2078
#
# Epoch 15        AvgLoss=0.467947
# Eval Recall@10=0.4054 NDCG@10=0.2082
#
# Epoch 16        AvgLoss=0.461172
# Eval Recall@10=0.4130 NDCG@10=0.2115
#
# Epoch 17        AvgLoss=0.455280
# Eval Recall@10=0.4120 NDCG@10=0.2104
#
# Epoch 18        AvgLoss=0.450032
# Eval Recall@10=0.4134 NDCG@10=0.2113
#
# Epoch 19        AvgLoss=0.445451
# Eval Recall@10=0.4117 NDCG@10=0.2109
#
# Epoch 20        AvgLoss=0.441330
# Eval Recall@10=0.4138 NDCG@10=0.2126
#
# Epoch 21        AvgLoss=0.437639
# Eval Recall@10=0.4163 NDCG@10=0.2143
#
# Epoch 22        AvgLoss=0.434386
# Eval Recall@10=0.4158 NDCG@10=0.2155
#
# Epoch 23        AvgLoss=0.431446
# Eval Recall@10=0.4170 NDCG@10=0.2165
#
# Epoch 24        AvgLoss=0.428797
# Eval Recall@10=0.4182 NDCG@10=0.2173
#
# Epoch 25        AvgLoss=0.426443
# Eval Recall@10=0.4189 NDCG@10=0.2168
#
# Epoch 26        AvgLoss=0.424295
# Eval Recall@10=0.4187 NDCG@10=0.2171
#
# Epoch 27        AvgLoss=0.422363
# Eval Recall@10=0.4212 NDCG@10=0.2178
#
# Epoch 28        AvgLoss=0.420599
# Eval Recall@10=0.4199 NDCG@10=0.2175
#
# Epoch 29        AvgLoss=0.418974
# Eval Recall@10=0.4199 NDCG@10=0.2179
#
# Epoch 30        AvgLoss=0.417513
# Eval Recall@10=0.4237 NDCG@10=0.2200
#
# Epoch 31        AvgLoss=0.416149
# Eval Recall@10=0.4229 NDCG@10=0.2193
#
# Epoch 32        AvgLoss=0.414895
# Eval Recall@10=0.4244 NDCG@10=0.2203
#
# Epoch 33        AvgLoss=0.413769
# Eval Recall@10=0.4249 NDCG@10=0.2197
#
# Epoch 34        AvgLoss=0.412709
# Eval Recall@10=0.4278 NDCG@10=0.2211
#
# Epoch 35        AvgLoss=0.411677
# Eval Recall@10=0.4265 NDCG@10=0.2200
#
# Epoch 36        AvgLoss=0.410786
# Eval Recall@10=0.4294 NDCG@10=0.2218
#
# Epoch 37        AvgLoss=0.409917
# Eval Recall@10=0.4316 NDCG@10=0.2223
#
# Epoch 38        AvgLoss=0.409090
# Eval Recall@10=0.4306 NDCG@10=0.2216
#
# Epoch 39        AvgLoss=0.408385
# Eval Recall@10=0.4299 NDCG@10=0.2212
#
# Epoch 40        AvgLoss=0.407660
# Eval Recall@10=0.4336 NDCG@10=0.2209
#
# Epoch 41        AvgLoss=0.406971
# Eval Recall@10=0.4323 NDCG@10=0.2225
#
# Epoch 42        AvgLoss=0.406301
# Eval Recall@10=0.4324 NDCG@10=0.2214
#
# Epoch 43        AvgLoss=0.405699
# Eval Recall@10=0.4333 NDCG@10=0.2218
#
# Epoch 44        AvgLoss=0.405101
# Eval Recall@10=0.4364 NDCG@10=0.2232
#
# Epoch 45        AvgLoss=0.404535
# Eval Recall@10=0.4341 NDCG@10=0.2216
#
# Epoch 46        AvgLoss=0.404060
# Eval Recall@10=0.4368 NDCG@10=0.2229
#
# Epoch 47        AvgLoss=0.403486
# Eval Recall@10=0.4322 NDCG@10=0.2213
#
# Epoch 48        AvgLoss=0.403002
# Eval Recall@10=0.4369 NDCG@10=0.2216
#
# Epoch 49        AvgLoss=0.402561
# Eval Recall@10=0.4356 NDCG@10=0.2223
#
# Epoch 50        AvgLoss=0.402110
# Eval Recall@10=0.4348 NDCG@10=0.2212
#
# Recall@10=0.4346 NDCG@10=0.2214

# %% [markdown]
# # 改进塔 + 时间感知

# %% [markdown]
# python models/behavior_tower_experiments/run_profile.py --profile improved_mean_decay --out_csv models/behavior_tower_experiments/result/improved_timeaware_mean_decay_profile_10epochs.csv

# %% [markdown]
# Epoch 1 AvgLoss=0.683435
# Eval Recall@10=0.1417 NDCG@10=0.0681
#
# Epoch 2 AvgLoss=0.665848
# Eval Recall@10=0.2312 NDCG@10=0.1112
#
# Epoch 3 AvgLoss=0.640717
# Eval Recall@10=0.3199 NDCG@10=0.1561
#
# Epoch 4 AvgLoss=0.610392
# Eval Recall@10=0.3634 NDCG@10=0.1793
#
# Epoch 5 AvgLoss=0.579681
# Eval Recall@10=0.3847 NDCG@10=0.1913
#
# Epoch 6 AvgLoss=0.551967
# Eval Recall@10=0.3928 NDCG@10=0.1964
#
# Epoch 7 AvgLoss=0.528325
# Eval Recall@10=0.3967 NDCG@10=0.1998
#
# Epoch 8 AvgLoss=0.508641
# Eval Recall@10=0.4027 NDCG@10=0.2026
#
# Epoch 9 AvgLoss=0.492394
# Eval Recall@10=0.4024 NDCG@10=0.2037
#
# Epoch 10        AvgLoss=0.478905
# Eval Recall@10=0.4030 NDCG@10=0.2046
#
# Epoch 11        AvgLoss=0.467702
# Eval Recall@10=0.4087 NDCG@10=0.2056
#
# Epoch 12        AvgLoss=0.458280
# Eval Recall@10=0.4059 NDCG@10=0.2053
#
# Epoch 13        AvgLoss=0.450402
# Eval Recall@10=0.4076 NDCG@10=0.2059
#
# Epoch 14        AvgLoss=0.443685
# Eval Recall@10=0.4077 NDCG@10=0.2084
#
# Epoch 15        AvgLoss=0.437946
# Eval Recall@10=0.4049 NDCG@10=0.2068
#
# Epoch 16        AvgLoss=0.433014
# Eval Recall@10=0.4081 NDCG@10=0.2082
#
# Epoch 17        AvgLoss=0.428776
# Eval Recall@10=0.4068 NDCG@10=0.2082
#
# Epoch 18        AvgLoss=0.425110
# Eval Recall@10=0.4072 NDCG@10=0.2096
#
# Epoch 19        AvgLoss=0.421905
# Eval Recall@10=0.4091 NDCG@10=0.2098
#
# Epoch 20        AvgLoss=0.419088
# Eval Recall@10=0.4113 NDCG@10=0.2118
#
# Epoch 21        AvgLoss=0.416609
# Eval Recall@10=0.4121 NDCG@10=0.2129
#
# Epoch 22        AvgLoss=0.414426
# Eval Recall@10=0.4129 NDCG@10=0.2149
#
# Epoch 23        AvgLoss=0.412448
# Eval Recall@10=0.4127 NDCG@10=0.2148
#
# Epoch 24        AvgLoss=0.410684
# Eval Recall@10=0.4149 NDCG@10=0.2159
#
# Epoch 25        AvgLoss=0.409100
# Eval Recall@10=0.4152 NDCG@10=0.2170
#
# Epoch 26        AvgLoss=0.407634
# Eval Recall@10=0.4144 NDCG@10=0.2170
#
# Epoch 27        AvgLoss=0.406307
# Eval Recall@10=0.4173 NDCG@10=0.2175
#
# Epoch 28        AvgLoss=0.405073
# Eval Recall@10=0.4199 NDCG@10=0.2184
#
# Epoch 29        AvgLoss=0.403935
# Eval Recall@10=0.4169 NDCG@10=0.2190
#
# Epoch 30        AvgLoss=0.402877
# Eval Recall@10=0.4214 NDCG@10=0.2206
#
# Epoch 31        AvgLoss=0.401879
# Eval Recall@10=0.4228 NDCG@10=0.2207
#
# Epoch 32        AvgLoss=0.400938
# Eval Recall@10=0.4228 NDCG@10=0.2214
#
# Epoch 33        AvgLoss=0.400062
# Eval Recall@10=0.4258 NDCG@10=0.2227
#
# Epoch 34        AvgLoss=0.399225
# Eval Recall@10=0.4257 NDCG@10=0.2227
#
# Epoch 35        AvgLoss=0.398445
# Eval Recall@10=0.4283 NDCG@10=0.2236
#
# Epoch 36        AvgLoss=0.397705
# Eval Recall@10=0.4324 NDCG@10=0.2267
#
# Epoch 37        AvgLoss=0.396984
# Eval Recall@10=0.4331 NDCG@10=0.2258
#
# Epoch 38        AvgLoss=0.396309
# Eval Recall@10=0.4346 NDCG@10=0.2257
#
# Epoch 39        AvgLoss=0.395675
# Eval Recall@10=0.4320 NDCG@10=0.2256
#
# Epoch 40        AvgLoss=0.395068
# Eval Recall@10=0.4375 NDCG@10=0.2263
#
# Epoch 41        AvgLoss=0.394471
# Eval Recall@10=0.4371 NDCG@10=0.2271
#
# Epoch 42        AvgLoss=0.393913
# Eval Recall@10=0.4352 NDCG@10=0.2266
#
# Epoch 43        AvgLoss=0.393378
# Eval Recall@10=0.4400 NDCG@10=0.2293
#
# Epoch 44        AvgLoss=0.392852
# Eval Recall@10=0.4408 NDCG@10=0.2286
#
# Epoch 45        AvgLoss=0.392355
# Eval Recall@10=0.4385 NDCG@10=0.2282
#
# Epoch 46        AvgLoss=0.391907
# Eval Recall@10=0.4395 NDCG@10=0.2268
#
# Epoch 47        AvgLoss=0.391434
# Eval Recall@10=0.4391 NDCG@10=0.2274
#
# Epoch 48        AvgLoss=0.390996
# Eval Recall@10=0.4415 NDCG@10=0.2284
#
# Epoch 49        AvgLoss=0.390582
# Eval Recall@10=0.4442 NDCG@10=0.2291
#
# Epoch 50        AvgLoss=0.390179
# Eval Recall@10=0.4425 NDCG@10=0.2298
#
# Recall@10=0.4433 NDCG@10=0.2298

# %% [markdown]
# # 改进塔 + 线性退火 + 时间感知

# %% [markdown]
# python models/behavior_tower_experiments/run_profile.py --profile improved_last_linear_decay --out_csv models/behavior_tower_experiments/result/improved_last_linear_decay_timeaware_50epochs.csv

# %% [markdown]
# Epoch 1 AvgLoss=0.666054
# Eval Recall@10=0.3217 NDCG@10=0.1621
#
# Epoch 2 AvgLoss=0.616298
# Eval Recall@10=0.3748 NDCG@10=0.1902
#
# Epoch 3 AvgLoss=0.576773
# Eval Recall@10=0.3948 NDCG@10=0.1997
#
# Epoch 4 AvgLoss=0.545553
# Eval Recall@10=0.4005 NDCG@10=0.2030
#
# Epoch 5 AvgLoss=0.521076
# Eval Recall@10=0.4048 NDCG@10=0.2049
#
# Epoch 6 AvgLoss=0.501752
# Eval Recall@10=0.4044 NDCG@10=0.2047
#
# Epoch 7 AvgLoss=0.486294
# Eval Recall@10=0.4031 NDCG@10=0.2045
#
# Epoch 8 AvgLoss=0.473763
# Eval Recall@10=0.4077 NDCG@10=0.2065
#
# Epoch 9 AvgLoss=0.463463
# Eval Recall@10=0.4021 NDCG@10=0.2055
#
# Epoch 10        AvgLoss=0.454902
# Eval Recall@10=0.4070 NDCG@10=0.2072
#
# Epoch 11        AvgLoss=0.447725
# Eval Recall@10=0.4104 NDCG@10=0.2068
#
# Epoch 12        AvgLoss=0.441624
# Eval Recall@10=0.4078 NDCG@10=0.2066
#
# Epoch 13        AvgLoss=0.436366
# Eval Recall@10=0.4067 NDCG@10=0.2067
#
# Epoch 14        AvgLoss=0.431851
# Eval Recall@10=0.4088 NDCG@10=0.2085
#
# Epoch 15        AvgLoss=0.427897
# Eval Recall@10=0.4052 NDCG@10=0.2076
#
# Epoch 16        AvgLoss=0.424497
# Eval Recall@10=0.4095 NDCG@10=0.2104
#
# Epoch 17        AvgLoss=0.421472
# Eval Recall@10=0.4092 NDCG@10=0.2106
#
# Epoch 18        AvgLoss=0.418836
# Eval Recall@10=0.4108 NDCG@10=0.2120
#
# Epoch 19        AvgLoss=0.416482
# Eval Recall@10=0.4116 NDCG@10=0.2129
#
# Epoch 20        AvgLoss=0.414396
# Eval Recall@10=0.4149 NDCG@10=0.2156
#
# Epoch 21        AvgLoss=0.412538
# Eval Recall@10=0.4158 NDCG@10=0.2164
#
# Epoch 22        AvgLoss=0.410865
# Eval Recall@10=0.4173 NDCG@10=0.2185
#
# Epoch 23        AvgLoss=0.409351
# Eval Recall@10=0.4170 NDCG@10=0.2177
#
# Epoch 24        AvgLoss=0.407955
# Eval Recall@10=0.4185 NDCG@10=0.2193
#
# Epoch 25        AvgLoss=0.406724
# Eval Recall@10=0.4216 NDCG@10=0.2196
#
# Epoch 26        AvgLoss=0.405505
# Eval Recall@10=0.4214 NDCG@10=0.2214
#
# Epoch 27        AvgLoss=0.404527
# Eval Recall@10=0.4265 NDCG@10=0.2217
#
# Epoch 28        AvgLoss=0.403405
# Eval Recall@10=0.4259 NDCG@10=0.2188
#
# Epoch 29        AvgLoss=0.402461
# Eval Recall@10=0.4260 NDCG@10=0.2204
#
# Epoch 30        AvgLoss=0.401587
# Eval Recall@10=0.4266 NDCG@10=0.2211
#
# Epoch 31        AvgLoss=0.400738
# Eval Recall@10=0.4293 NDCG@10=0.2220
#
# Epoch 32        AvgLoss=0.399919
# Eval Recall@10=0.4303 NDCG@10=0.2211
#
# Epoch 33        AvgLoss=0.399201
# Eval Recall@10=0.4321 NDCG@10=0.2217
#
# Epoch 34        AvgLoss=0.398285
# Eval Recall@10=0.4355 NDCG@10=0.2233
#
# Epoch 35        AvgLoss=0.397562
# Eval Recall@10=0.4360 NDCG@10=0.2237
#
# Epoch 36        AvgLoss=0.396868
# Eval Recall@10=0.4394 NDCG@10=0.2247
#
# Epoch 37        AvgLoss=0.396164
# Eval Recall@10=0.4385 NDCG@10=0.2233
#
# Epoch 38        AvgLoss=0.395537
# Eval Recall@10=0.4393 NDCG@10=0.2239
#
# Epoch 39        AvgLoss=0.394887
# Eval Recall@10=0.4394 NDCG@10=0.2239
#
# Epoch 40        AvgLoss=0.394228
# Eval Recall@10=0.4436 NDCG@10=0.2246
#
# Epoch 41        AvgLoss=0.393639
# Eval Recall@10=0.4440 NDCG@10=0.2247
#
# Epoch 42        AvgLoss=0.393055
# Eval Recall@10=0.4377 NDCG@10=0.2223
#
# Epoch 43        AvgLoss=0.392511
# Eval Recall@10=0.4440 NDCG@10=0.2239
#
# Epoch 44        AvgLoss=0.391991
# Eval Recall@10=0.4469 NDCG@10=0.2261
#
# Epoch 45        AvgLoss=0.391452
# Eval Recall@10=0.4451 NDCG@10=0.2248
#
# Epoch 46        AvgLoss=0.390944
# Eval Recall@10=0.4446 NDCG@10=0.2252
#
# Epoch 47        AvgLoss=0.390624
# Eval Recall@10=0.4415 NDCG@10=0.2233
#
# Epoch 48        AvgLoss=0.389965
# Eval Recall@10=0.4456 NDCG@10=0.2236
#
# Epoch 49        AvgLoss=0.389535
# Eval Recall@10=0.4470 NDCG@10=0.2241
#
# Epoch 50        AvgLoss=0.389121
# Eval Recall@10=0.4431 NDCG@10=0.2229
#
# Recall@10=0.4459 NDCG@10=0.2238

# %% [markdown]
# # 双向GRU + 时间注意力

# %% [markdown]
# python models/behavior_tower_experiments/run_profile.py --profile timeaware_attention_bigru --out_csv models/behavior_tower_experiments/result/timeaware_attention_bigru_50epochs.cs

# %% [markdown]
# Epoch 1 AvgLoss=0.552196
# Eval Recall@10=0.3760 NDCG@10=0.1892
#
# Epoch 2 AvgLoss=0.427248
# Eval Recall@10=0.3962 NDCG@10=0.2003
#
# Epoch 3 AvgLoss=0.414225
# Eval Recall@10=0.4011 NDCG@10=0.2031
#
# Epoch 4 AvgLoss=0.411342
# Eval Recall@10=0.4009 NDCG@10=0.2029
#
# Epoch 5 AvgLoss=0.409994
# Eval Recall@10=0.4020 NDCG@10=0.2033
#
# Epoch 6 AvgLoss=0.409059
# Eval Recall@10=0.4027 NDCG@10=0.2040
#
# Epoch 7 AvgLoss=0.408287
# Eval Recall@10=0.4014 NDCG@10=0.2050
#
# Epoch 8 AvgLoss=0.407525
# Eval Recall@10=0.4068 NDCG@10=0.2080
#
# Epoch 9 AvgLoss=0.406715
# Eval Recall@10=0.4056 NDCG@10=0.2083
#
# Epoch 10        AvgLoss=0.405737
# Eval Recall@10=0.4120 NDCG@10=0.2109
#
# Epoch 11        AvgLoss=0.404349
# Eval Recall@10=0.4173 NDCG@10=0.2127
#
# Epoch 12        AvgLoss=0.402412
# Eval Recall@10=0.4239 NDCG@10=0.2148
#
# Epoch 13        AvgLoss=0.399754
# Eval Recall@10=0.4278 NDCG@10=0.2158
#
# Epoch 14        AvgLoss=0.396568
# Eval Recall@10=0.4300 NDCG@10=0.2158
#
# Epoch 15        AvgLoss=0.393478
# Eval Recall@10=0.4348 NDCG@10=0.2173
#
# Epoch 16        AvgLoss=0.390515
# Eval Recall@10=0.4320 NDCG@10=0.2156
#
# Epoch 17        AvgLoss=0.387972
# Eval Recall@10=0.4357 NDCG@10=0.2153
#
# Epoch 18        AvgLoss=0.385996
# Eval Recall@10=0.4362 NDCG@10=0.2152
#
# Epoch 19        AvgLoss=0.384571
# Eval Recall@10=0.4386 NDCG@10=0.2154
#
# Epoch 20        AvgLoss=0.383619
# Eval Recall@10=0.4355 NDCG@10=0.2116
#
# Epoch 21        AvgLoss=0.382716
# Eval Recall@10=0.4355 NDCG@10=0.2122
#
# Epoch 22        AvgLoss=0.382202
# Eval Recall@10=0.4369 NDCG@10=0.2131
#
# Epoch 23        AvgLoss=0.381701
# Eval Recall@10=0.4325 NDCG@10=0.2098
#
# Epoch 24        AvgLoss=0.381290
# Eval Recall@10=0.4355 NDCG@10=0.2127
#
# Epoch 25        AvgLoss=0.380866
# Eval Recall@10=0.4345 NDCG@10=0.2121
#
# Epoch 26        AvgLoss=0.380663
# Eval Recall@10=0.4360 NDCG@10=0.2148
#
# Epoch 27        AvgLoss=0.380372
# Eval Recall@10=0.4394 NDCG@10=0.2149
#
# Epoch 28        AvgLoss=0.380134
# Eval Recall@10=0.4416 NDCG@10=0.2165
#
# Epoch 29        AvgLoss=0.379920
# Eval Recall@10=0.4426 NDCG@10=0.2163
#
# Epoch 30        AvgLoss=0.379656
# Eval Recall@10=0.4404 NDCG@10=0.2169
#
# Epoch 31        AvgLoss=0.379292
# Eval Recall@10=0.4433 NDCG@10=0.2173
#
# Epoch 32        AvgLoss=0.378964
# Eval Recall@10=0.4440 NDCG@10=0.2191
#
# Epoch 33        AvgLoss=0.378586
# Eval Recall@10=0.4487 NDCG@10=0.2187
#
# Epoch 34        AvgLoss=0.378204
# Eval Recall@10=0.4501 NDCG@10=0.2224
#
# Epoch 35        AvgLoss=0.377810
# Eval Recall@10=0.4506 NDCG@10=0.2214
#
# Epoch 36        AvgLoss=0.377399
# Eval Recall@10=0.4525 NDCG@10=0.2227
#
# Epoch 37        AvgLoss=0.376996
# Eval Recall@10=0.4578 NDCG@10=0.2268
#
# Epoch 38        AvgLoss=0.376588
# Eval Recall@10=0.4571 NDCG@10=0.2246
#
# Epoch 39        AvgLoss=0.376175
# Eval Recall@10=0.4595 NDCG@10=0.2288
#
# Epoch 40        AvgLoss=0.375764
# Eval Recall@10=0.4653 NDCG@10=0.2285
#
# Epoch 41        AvgLoss=0.375381
# Eval Recall@10=0.4641 NDCG@10=0.2306
#
# Epoch 42        AvgLoss=0.375133
# Eval Recall@10=0.4618 NDCG@10=0.2283
#
# Epoch 43        AvgLoss=0.374693
# Eval Recall@10=0.4658 NDCG@10=0.2296
#
# Epoch 44        AvgLoss=0.374337
# Eval Recall@10=0.4666 NDCG@10=0.2307
#
# Epoch 45        AvgLoss=0.374085
# Eval Recall@10=0.4698 NDCG@10=0.2328
#
# Epoch 46        AvgLoss=0.373847
# Eval Recall@10=0.4688 NDCG@10=0.2321
#
# Epoch 47        AvgLoss=0.373577
# Eval Recall@10=0.4658 NDCG@10=0.2302
#
# Epoch 48        AvgLoss=0.373474
# Eval Recall@10=0.4703 NDCG@10=0.2317
#
# Epoch 49        AvgLoss=0.373298
# Eval Recall@10=0.4718 NDCG@10=0.2327
#
# Epoch 50        AvgLoss=0.373105
# Eval Recall@10=0.4672 NDCG@10=0.2313
#
# Recall@10=0.4693 NDCG@10=0.2308
