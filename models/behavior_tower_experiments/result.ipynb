# %% [markdown]
# # 基线塔

# %% [markdown]
# python models/behavior_tower_experiments/run_experiments.py --tower baseline --emb_dim 128 --epochs {} --lr 1e-3 --batch_size 256 --neg 1 --k 10 --num_neg 100 --seed 42 --save_csv results_baseline_{}epochs.csv

# %% [markdown]
# Epoch 1 AvgLoss=0.672580
#
# Epoch 2 AvgLoss=0.624471
#
# Epoch 3 AvgLoss=0.585424
#
# Epoch 4 AvgLoss=0.553355
#
# Epoch 5 AvgLoss=0.527583
#
# Epoch 6 AvgLoss=0.507379
#
# Epoch 7 AvgLoss=0.490819
#
# Epoch 8 AvgLoss=0.476758
#
# Epoch 9 AvgLoss=0.465423
#
# Epoch 10        AvgLoss=0.455958
#
# Epoch 11        AvgLoss=0.447942
#
# Epoch 12        AvgLoss=0.441116
#
# Epoch 13        AvgLoss=0.435517
#
# Epoch 14        AvgLoss=0.434434
#
# Epoch 15        AvgLoss=0.427808
#
# Epoch 16        AvgLoss=0.423287
#
# Epoch 17        AvgLoss=0.419499
#
# Epoch 18        AvgLoss=0.416273
#
# Epoch 19        AvgLoss=0.413644
#
# Epoch 20        AvgLoss=0.410924
#
# 3 epochs Recall@10=0.3916 NDCG@10=0.1983
#
# 5 epochs Recall@10=0.4070 NDCG@10=0.2061
#
# 7 epochs Recall@10=0.4104 NDCG@10=0.2093
#
# 10 epochs Recall@10=0.4123 NDCG@10=0.2110
#
# 13 epochs Recall@10=0.4078 NDCG@10=0.2086
#
# 15 epochs Recall@10=0.4201 NDCG@10=0.2189
#
# 17 epochs Recall@10=0.4237 NDCG@10=0.2225
#
# 20 epochs Recall@10=0.4301 NDCG@10=0.2271

# %% [markdown]
# # 改进塔

# %% [markdown]
# python models/behavior_tower_experiments/run_experiments.py --tower improved --pool last --emb_dim 128 --epochs 3 --lr 1e-3 --batch_size 256 --seed 42
#
# Epoch 1 AvgLoss=0.673197
#
# Epoch 2 AvgLoss=0.625075
#
# Epoch 3 AvgLoss=0.586037
#
# Epoch 4 AvgLoss=0.554116
#
# Epoch 5 AvgLoss=0.528206
#
# Epoch 6 AvgLoss=0.507440
#
# Epoch 7 AvgLoss=0.490689
#
# Epoch 8 AvgLoss=0.477053
#
# Epoch 9 AvgLoss=0.465738
#
# Epoch 10        AvgLoss=0.456520
#
# Epoch 11        AvgLoss=0.449273
#
# Epoch 12        AvgLoss=0.442067
#
# Epoch 13        AvgLoss=0.436083
#
# Epoch 14        AvgLoss=0.431062
#
# Epoch 15        AvgLoss=0.426661
#
# Epoch 16        AvgLoss=0.427631
#
# Epoch 17        AvgLoss=0.421810
#
# Epoch 18        AvgLoss=0.418112
#
# Epoch 19        AvgLoss=0.415175
#
# Epoch 20        AvgLoss=0.412626
#
# 3 epochs Recall@10=0.3913 NDCG@10=0.1979
#
# 5 epochs Recall@10=0.4066 NDCG@10=0.2059
#
# 7 epochs Recall@10=0.4088 NDCG@10=0.2079
#
# 10 epochs Recall@10=0.4105 NDCG@10=0.2088
#
# 13 epochs Recall@10=0.4173 NDCG@10=0.2154
#
# 15 epochs Recall@10=0.4173 NDCG@10=0.2170
#
# 17 epochs Recall@10=0.4197 NDCG@10=0.2192
#
# 20 epochs Recall@10=0.4259 NDCG@10=0.2246

# %% [markdown]
# python models/behavior_tower_experiments/run_experiments.py --tower improved --pool mean --emb_dim 128
#
# Recall@10=0.0858 NDCG@10=0.0368

# %% [markdown]
# python models/behavior_tower_experiments/run_experiments.py --tower improved --pool mean --decay 0.9 --emb_dim 128
# Recall@10=0.0903 NDCG@10=0.0396
